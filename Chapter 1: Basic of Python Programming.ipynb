# %% [markdown]
# 1. Write a program to calculate bodymass index BMI of a person. (bmi = kg/m^2)

# %%
w= float(input("input your weight in kg:"))
h= float(input("input your height in cm:"))
hm= h/100

bmi = w/(hm*hm)

print("your BMI is {bmi:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3226/1559989062.py in <cell line: 0>()
# ----> 1 w= float(input("input your weight in kg:"))
#       2 h= float(input("input your height in cm:"))
#       3 hm= h/100
#       4
#       5 bmi = w/(hm*hm)
#
# ValueError: could not convert string to float: ''
